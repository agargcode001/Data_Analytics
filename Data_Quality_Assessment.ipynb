# %%
#transactions: ts
#customer_demographics: cd
#customer_address: ca
#new_customer_list: ncl
import pandas as pd
import numpy as np
xls = pd.ExcelFile('KPMG_VI_New_raw_data_update_final.xlsx')
ts = pd.read_excel(xls,'Transactions')
ncl = pd.read_excel(xls, 'NewCustomerList')
cd = pd.read_excel(xls, 'CustomerDemographic')
ca = pd.read_excel(xls, 'CustomerAddress')

# %%
ncl
# Out:
#     first_name      last_name  gender  past_3_years_bike_related_purchases  \
# 0      Marinna       Kauschke  Female                                   21
# 1         Olia      O' Mullan  Female                                   77
# 2     Brigitte       Whellams  Female                                   67
# 3          Ivy           Farr  Female                                   56
# 4     Beverlee     Ungerechts  Female                                   49
# 5        Skipp         Swales    Male                                   15
# 6     Leighton       Firbanks    Male                                   51
# 7    Claudetta  Ricciardiello  Female                                   61
# 8      Harland      Messenger    Male                                   90
# 9       Babara         Sissel  Female                                   50
# 10    Cariotta            NaN  Female                                   10
# ...

# %%
ncl['country'].unique()
# Out:
# array(['Australia'], dtype=object)
